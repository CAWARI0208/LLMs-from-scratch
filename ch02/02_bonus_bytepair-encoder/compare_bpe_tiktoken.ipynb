# %% [markdown]
# <a href="https://colab.research.google.com/github/CAWARI0208/LLMs-from-scratch/blob/main/ch02/02_bonus_bytepair-encoder/compare_bpe_tiktoken.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 徹底清空目前的環境（確保沒有殘留的髒檔案）
# %cd /content
# !rm -rf LLMs-from-scratch

# 2. 複製你 Fork 後的完整 GitHub 專案
# （請把下面的「你的帳號」換成你自己的 GitHub 帳號名稱）
# !git clone https://github.com/CAWARI0208/LLMs-from-scratch

# 3. 將 Colab 的工作目錄「切換進去」專案資料夾內（非常關鍵！）
# %cd /content/LLMs-from-scratch

# 4. 安裝專案執行所需的 Python 附件套件
# !pip install tiktoken tqdm matplotlib

# 5. 檢查當前目錄，確認附件都在
# !ls -R
# Out:
# /content
# Cloning into 'LLMs-from-scratch'...
# remote: Enumerating objects: 7357, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 7357 (delta 8), reused 1 (delta 1), pack-reused 7336 (from 2)
# Receiving objects: 100% (7357/7357), 16.54 MiB | 22.64 MiB/s, done.
# Resolving deltas: 100% (4486/4486), done.
# /content/LLMs-from-scratch
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken) (2026.6.17)
# .:
# appendix-A  ch01  ch06		pixi.toml		requirements.txt
# appendix-B  ch02  ch07		pkg			setup
# appendix-C  ch03  CITATION.cff	pyproject.toml		troubleshooting.md
# appendix-D  ch04  conftest.py	README.md
# appendix-E  ch05  LICENSE.txt	reasoning-from-scratch
#
# ./appendix-A:
# 01_main-chapter-code  02_setup-recommendations	README.md
#
# ./appendix-A/01_main-chapter-code:
# code-part1.ipynb  DDP-script.py		  exercise-solutions.ipynb
# code-part2.ipynb  DDP-script-torchrun.py  README.md
#
# ./appendix-A/02_setup-recommendations:
# README.md
#
# ./appendix-B:
# README.md
#
# ./appendix-C:
# README.md
#
# ./appendix-D:
# 01_main-chapter-code  README.md
#
# ./appendix-D/01_main-chapter-code:
# appendix-D.ipynb  previous_chapters.py	the-verdict.txt
#
# ./appendix-E:
# 01_main-chapter-code  README.md
#
# ./appendix-E/01_main-chapter-code:
# appendix-E.ipynb  gpt_download.py  previous_chapters.py
#
# ./ch01:
# reading-recommendations.md  README.md
#
# ./ch02:
# 01_main-chapter-code	   03_bonus_embedding-vs-matmul   05_bpe-from-scratch
# 02_bonus_bytepair-encoder  04_bonus_dataloader-intuition  README.md
#
# ./ch02/01_main-chapter-code:
# ch02.ipynb	  exercise-solutions.ipynb  the-verdict.txt
# dataloader.ipynb  README.md
#
# ./ch02/02_bonus_bytepair-encoder:
# bpe_openai_gpt2.py	    gpt2_model	requirements-extra.txt
# compare-bpe-tiktoken.ipynb  README.md
#
# ./ch02/02_bonus_bytepair-encoder/gpt2_model:
# encoder.json  vocab.bpe
#
# ./ch02/03_bonus_embedding-vs-matmul:
# embeddings-and-linear-layers.ipynb  README.md
#
# ./ch02/04_bonus_dataloader-intuition:
# dataloader-intuition.ipynb  README.md
#
# ./ch02/05_bpe-from-scratch:
# bpe-from-scratch.ipynb	bpe-from-scratch-simple.ipynb  README.md  tests.py
#
# ./ch03:
# 01_main-chapter-code			03_understanding-buffers
# 02_bonus_efficient-multihead-attention	README.md
#
# ./ch03/01_main-chapter-code:
# ch03.ipynb		  multihead-attention.ipynb  small-text-sample.txt
# exercise-solutions.ipynb  README.md
#
# ./ch03/02_bonus_efficient-multihead-attention:
# mha-implementations.ipynb  README.md  tests
#
# ./ch03/02_bonus_efficient-multihead-attention/tests:
# test_mha_implementations.py
#
# ./ch03/03_understanding-buffers:
# README.md  understanding-buffers.ipynb
#
# ./ch04:
# 01_main-chapter-code	 04_gqa  07_moe       10_kv-sharing
# 02_performance-analysis  05_mla  08_deltanet  README.md
# 03_kv-cache		 06_swa  09_dsa
#
# ./ch04/01_main-chapter-code:
# ch04.ipynb		  gpt.py		README.md
# exercise-solutions.ipynb  previous_chapters.py	tests.py
#
# ./ch04/02_performance-analysis:
# flops-analysis.ipynb  README.md  requirements-extra.txt
#
# ./ch04/03_kv-cache:
# gpt_ch04.py			gpt_with_kv_cache.py  tests.py
# gpt_with_kv_cache_optimized.py	README.md
#
# ./ch04/04_gqa:
# gpt_with_kv_gqa.py  memory_estimator_gqa.py	  README.md
# gpt_with_kv_mha.py  plot_memory_estimates_gqa.py
#
# ./ch04/05_mla:
# gpt_with_kv_mha.py  memory_estimator_mla.py	  README.md
# gpt_with_kv_mla.py  plot_memory_estimates_mla.py
#
# ./ch04/06_swa:
# gpt_with_kv_mha.py  memory_estimator_swa.py	  README.md
# gpt_with_kv_swa.py  plot_memory_estimates_swa.py  tests.py
#
# ./ch04/07_moe:
# gpt_with_kv_ffn.py  memory_estimator_moe.py	  README.md
# gpt_with_kv_moe.py  plot_memory_estimates_moe.py
#
# ./ch04/08_deltanet:
# plot_memory_estimates_gated_deltanet.py  README.md
#
# ./ch04/09_dsa:
# gpt_with_kv_dsa.py  README.md  test_dsa.py
#
# ./ch04/10_kv-sharing:
# gemma4-kv-sharing.webp
# gpt_with_kv_mha.py
# gpt_with_kv_sharing.py
# kv_memory_mha_gqa_kvsharing_gemma4_e2b.webp
# kv_memory_mha_gqa_kvsharing_gemma4_e4b.webp
# memory_estimator_kv_sharing.py
# plot_memory_estimates_kv_sharing.py
# README.md
# tests.py
#
# ./ch05:
# 01_main-chapter-code		    11_qwen3
# 02_alternative_weight_loading	    12_gemma3
# 03_bonus_pretraining_on_gutenberg   13_olmo3
# 04_learning_rate_schedulers	    14_ch05_with_other_llms
# 05_bonus_hparam_tuning		    15_tiny-aya
# 06_user_interface		    16_qwen3.5
# 07_gpt_to_llama			    17_gemma4
# 08_memory_efficient_weight_loading  18_muon
# 09_extending-tokenizers		    README.md
# 10_llm-training-speed
#
# ./ch05/01_main-chapter-code:
# ch05.ipynb		  gpt_download.py  gpt_train.py		 README.md
# exercise-solutions.ipynb  gpt_generate.py  previous_chapters.py  tests.py
#
# ./ch05/02_alternative_weight_loading:
# README.md			     weight-loading-hf-transformers.ipynb
# weight-loading-hf-safetensors.ipynb  weight-loading-pytorch.ipynb
#
# ./ch05/03_bonus_pretraining_on_gutenberg:
# prepare_dataset.py  pretraining_simple.py  README.md  tests.py
#
# ./ch05/04_learning_rate_schedulers:
# README.md
#
# ./ch05/05_bonus_hparam_tuning:
# hparam_search.py  README.md  the-verdict.txt
#
# ./ch05/06_user_interface:
# app_orig.py  app_own.py  README.md  requirements-extra.txt
#
# ./ch05/07_gpt_to_llama:
# config.json			   README.md
# converting-gpt-to-llama2.ipynb	   requirements-extra.txt
# converting-llama2-to-llama3.ipynb  standalone-llama32.ipynb
# previous_chapters.py		   tests
#
# ./ch05/07_gpt_to_llama/tests:
# test_llama32_nb.py  test-requirements-extra.txt  tests_rope_and_parts.py
#
# ./ch05/08_memory_efficient_weight_loading:
# memory-efficient-state-dict.ipynb  previous_chapters.py  README.md
#
# ./ch05/09_extending-tokenizers:
# extend-tiktoken.ipynb  README.md
#
# ./ch05/10_llm-training-speed:
# 00_orig.py  01_opt_single_gpu.py  02_opt_multi_gpu_ddp.py  README.md
#
# ./ch05/11_qwen3:
# qwen3-chat-interface	standalone-qwen3-moe.ipynb		 tests
# README.md		standalone-qwen3-moe-plus-kvcache.ipynb
# standalone-qwen3.ipynb	standalone-qwen3-plus-kvcache.ipynb
#
# ./ch05/11_qwen3/qwen3-chat-interface:
# public				   README.md
# qwen3-chat-interface-multiturn.py  requirements-extra.txt
# qwen3-chat-interface.py
#
# ./ch05/11_qwen3/qwen3-chat-interface/public:
# logo_dark.webp	logo_light.webp
#
# ./ch05/11_qwen3/tests:
# test_qwen3_kvcache_nb.py  test_qwen3_nb.py
#
# ./ch05/12_gemma3:
# README.md  standalone-gemma3.ipynb  standalone-gemma3-plus-kvcache.ipynb  tests
#
# ./ch05/12_gemma3/tests:
# gemma3_layer_debugger_detailed.py  test_gemma3_kv_nb.py
# gemma3_layer_debugger.py	   test_gemma3_nb.py
# gemma3-transformers-ref.ipynb
#
# ./ch05/13_olmo3:
# README.md  standalone-olmo3.ipynb  standalone-olmo3-plus-kv-cache.ipynb  tests
#
# ./ch05/13_olmo3/tests:
# olmo3_layer_debugger.py  test_olmo3_kvcache_nb.py  test_olmo3_nb.py
#
# ./ch05/14_ch05_with_other_llms:
# ch05-llama32.ipynb  ch05-qwen3.ipynb  README.md
#
# ./ch05/15_tiny-aya:
# README.md		   standalone-tiny-aya-plus-kv-cache.ipynb
# standalone-tiny-aya.ipynb  tests
#
# ./ch05/15_tiny-aya/tests:
# test_tiny_aya_kvcache_nb.py  test_tiny_aya_nb.py  tiny_aya_layer_debugger.py
#
# ./ch05/16_qwen3.5:
# qwen3.5.ipynb		     qwen3_5_transformers.py  tests
# qwen3.5-plus-kv-cache.ipynb  README.md
#
# ./ch05/16_qwen3.5/tests:
# qwen3_5_layer_debugger.py  test_qwen3_5_nb.py
#
# ./ch05/17_gemma4:
# README.md  standalone-gemma4.ipynb  standalone-gemma4-plus-kvcache.ipynb  tests
#
# ./ch05/17_gemma4/tests:
# test_e2b  test_e4b  test_gemma4_nb.py
#
# ./ch05/17_gemma4/tests/test_e2b:
# gemma4_e2b_layer_debugger.py  gemma4-e2b-transformers-ref.ipynb
#
# ./ch05/17_gemma4/tests/test_e4b:
# gemma4_e4b_layer_debugger.py  gemma4-e4b-transformers-ref.ipynb
#
# ./ch05/18_muon:
# gpt_train_muon.py  gpt_train.py  previous_chapters.py  README.md
#
# ./ch06:
# 01_main-chapter-code		 03_bonus_imdb-classification  README.md
# 02_bonus_additional-experiments  04_user_interface
#
# ./ch06/01_main-chapter-code:
# ch06.ipynb		  gpt_download.py	      README.md
# exercise-solutions.ipynb  load-finetuned-model.ipynb  tests.py
# gpt_class_finetune.py	  previous_chapters.py
#
# ./ch06/02_bonus_additional-experiments:
# additional_experiments.py  gpt_download.py  previous_chapters.py  README.md
#
# ./ch06/03_bonus_imdb-classification:
# download_prepare_dataset.py  requirements-extra.txt  train_gpt_muon.py
# gpt_download.py		     sklearn-baseline.ipynb  train_gpt.py
# previous_chapters.py	     train_bert_hf.py	     train_sklearn_logreg.py
# README.md		     train_bert_hf_spam.py
#
# ./ch06/04_user_interface:
# app.py	README.md  requirements-extra.txt
#
# ./ch07:
# 01_main-chapter-code  04_preference-tuning-with-dpo  README.md
# 02_dataset-utilities  05_dataset-generation
# 03_model-evaluation   06_user_interface
#
# ./ch07/01_main-chapter-code:
# ch07.ipynb		       instruction-data-with-response.json
# exercise_experiments.py        load-finetuned-model.ipynb
# exercise-solutions.ipynb       ollama_evaluate.py
# gpt_download.py		       previous_chapters.py
# gpt_instruction_finetuning.py  README.md
# instruction-data.json	       tests.py
#
# ./ch07/02_dataset-utilities:
# config.json			    instruction-examples-modified.json
# create-passive-voice-entries.ipynb  README.md
# find-near-duplicates.py		    requirements-extra.txt
# instruction-examples.json
#
# ./ch07/03_model-evaluation:
# config.json			   llm-instruction-eval-openai.ipynb  scores
# eval-example-data.json		   README.md
# llm-instruction-eval-ollama.ipynb  requirements-extra.txt
#
# ./ch07/03_model-evaluation/scores:
# correlation-analysis.ipynb  llama3-8b-model-1-response.json
# gpt4-model-1-response.json  llama3-8b-model-2-response.json
# gpt4-model-2-response.json
#
# ./ch07/04_preference-tuning-with-dpo:
# create-preference-data-ollama.ipynb    previous_chapters.py
# dpo-from-scratch.ipynb		       README.md
# instruction-data-with-preference.json
#
# ./ch07/05_dataset-generation:
# config.json			 llama3-ollama.ipynb  reflection-gpt4.ipynb
# instruction-data-llama3-7b.json  README.md	      requirements-extra.txt
#
# ./ch07/06_user_interface:
# app.py	README.md  requirements-extra.txt
#
# ./pkg:
# llms_from_scratch
#
# ./pkg/llms_from_scratch:
# appendix_a.py  ch02.py	ch05.py  generate.py  kv_cache_batched	README.md
# appendix_d.py  ch03.py	ch06.py  __init__.py  llama3.py		tests
# appendix_e.py  ch04.py	ch07.py  kv_cache     qwen3.py		utils.py
#
# ./pkg/llms_from_scratch/kv_cache:
# generate.py  gpt2.py  __init__.py  llama3.py  qwen3.py	utils.py
#
# ./pkg/llms_from_scratch/kv_cache_batched:
# generate.py  __init__.py  qwen3.py  utils.py
#
# ./pkg/llms_from_scratch/tests:
# test_appendix_a.py  test_ch03.py  test_ch07.py		 test_qwen3.py
# test_appendix_d.py  test_ch04.py  test_generate.py
# test_appendix_e.py  test_ch05.py  test_kv_cache_gpt2.py
# test_ch02.py	    test_ch06.py  test_llama3.py
#
# ./reasoning-from-scratch:
#
# ./setup:
# 01_optional-python-setup-preferences  04_optional-aws-sagemaker-notebook
# 02_installing-python-libraries	      README.md
# 03_optional-docker-environment
#
# ./setup/01_optional-python-setup-preferences:
# native-pixi.md	native-uv.md  README.md
#
# ./setup/02_installing-python-libraries:
# python_environment_check.ipynb	README.md
# python_environment_check.py	tests.py
#
# ./setup/03_optional-docker-environment:
# README.md
#
# ./setup/04_optional-aws-sagemaker-notebook:
# cloudformation-template.yml  README.md

# %%
# 1. 切換到檔案所在的精準路徑（請根據你的專案資料夾結構調整）
# %cd /content/LLMs-from-scratch/ch02/02_bonus_bytepair-encoder/

# 2. 檢查一下清單，確認有沒有看到 bpe_openai_gpt2.py
# !ls
# Out:
# /content/LLMs-from-scratch/ch02/02_bonus_bytepair-encoder
# bpe_openai_gpt2.py	    gpt2_model	requirements-extra.txt
# compare-bpe-tiktoken.ipynb  README.md

# %%
# !python bpe_openai_gpt2.py

# %% [markdown]
# <table style="width:100%">
# <tr>
# <td style="vertical-align:middle; text-align:left;">
# <font size="2">
# Supplementary code for the <a href="http://mng.bz/orYv">Build a Large Language Model From Scratch</a> book by <a href="https://sebastianraschka.com">Sebastian Raschka</a><br>
# <br>Code repository: <a href="https://github.com/rasbt/LLMs-from-scratch">https://github.com/rasbt/LLMs-from-scratch</a>
# </font>
# </td>
# <td style="vertical-align:middle; text-align:left;">
# <a href="http://mng.bz/orYv"><img src="https://sebastianraschka.com/images/LLMs-from-scratch-images/cover-small.webp" width="100px"></a>
# </td>
# </tr>
# </table>

# %% [markdown]
# - Install the additional package requirements for this bonus notebook by uncommenting and running the following cell:

# %%
# pip install -r requirements-extra.txt

# %% [markdown]
# # Comparing Various Byte Pair Encoding (BPE) Implementations

# %% [markdown]
# <br>
# &nbsp;
#
# ## 1. Using BPE from `tiktoken`

# %%
from importlib.metadata import version

print("tiktoken version:", version("tiktoken"))
# Out:
# tiktoken version: 0.13.0

# %%
import tiktoken

tik_tokenizer = tiktoken.get_encoding("gpt2")

text = "Hello, world. Is this-- a test?"

# %%
integers = tik_tokenizer.encode(text, allowed_special={"<|endoftext|>"})

print(integers)
# Out:
# [15496, 11, 995, 13, 1148, 428, 438, 257, 1332, 30]

# %%
strings = tik_tokenizer.decode(integers)

print(strings)
# Out:
# Hello, world. Is this-- a test?

# %%
print(tik_tokenizer.n_vocab)
# Out:
# 50257

# %% [markdown]
# <br>
# &nbsp;
#
# ## 2. Using the original BPE implementation used in GPT-2

# %%
from bpe_openai_gpt2 import get_encoder, download_vocab

# %%
download_vocab()
# Out:
# Fetching encoder.json: 1.04Mit [00:00, 4.32Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 2.43Mit/s]

# %%
orig_tokenizer = get_encoder(model_name="gpt2_model", models_dir=".")

# %%
integers = orig_tokenizer.encode(text)

print(integers)
# Out:
# [15496, 11, 995, 13, 1148, 428, 438, 257, 1332, 30]

# %%
strings = orig_tokenizer.decode(integers)

print(strings)
# Out:
# Hello, world. Is this-- a test?

# %% [markdown]
# <br>
# &nbsp;
#
# ## 3. Using the BPE via Hugging Face transformers

# %%
import transformers

transformers.__version__
# Out:
# '5.13.1'

# %%
from transformers import GPT2Tokenizer

hf_tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
hf_tokenizer(strings)["input_ids"]
# Out:
# [15496, 11, 995, 13, 1148, 428, 438, 257, 1332, 30]

# %%
from transformers import GPT2TokenizerFast

hf_tokenizer_fast = GPT2TokenizerFast.from_pretrained("gpt2")

# %%
hf_tokenizer_fast(strings)["input_ids"]
# Out:
# [15496, 11, 995, 13, 1148, 428, 438, 257, 1332, 30]

# %% [markdown]
# <br>
# &nbsp;
#
# ## 4. Using my own from-scratch BPE tokenizer

# %%
import os
import sys
import io
import nbformat
import types

def import_from_notebook():
    def import_definitions_from_notebook(fullname, names):
        current_dir = os.getcwd()
        path = os.path.join(current_dir, "..", "05_bpe-from-scratch", fullname + ".ipynb")
        path = os.path.normpath(path)

        # Load the notebook
        if not os.path.exists(path):
            raise FileNotFoundError(f"Notebook file not found at: {path}")

        with io.open(path, "r", encoding="utf-8") as f:
            nb = nbformat.read(f, as_version=4)

        # Create a module to store the imported functions and classes
        mod = types.ModuleType(fullname)
        sys.modules[fullname] = mod

        # Go through the notebook cells and only execute function or class definitions
        for cell in nb.cells:
            if cell.cell_type == "code":
                cell_code = cell.source
                for name in names:
                    # Check for function or class definitions
                    if f"def {name}" in cell_code or f"class {name}" in cell_code:
                        exec(cell_code, mod.__dict__)
        return mod

    fullname = "bpe-from-scratch"
    names = ["BPETokenizerSimple"]

    return import_definitions_from_notebook(fullname, names)

# %%
imported_module = import_from_notebook()
BPETokenizerSimple = getattr(imported_module, "BPETokenizerSimple", None)

tokenizer_gpt2 = BPETokenizerSimple()
tokenizer_gpt2.load_vocab_and_merges_from_openai(
    vocab_path=os.path.join("gpt2_model", "encoder.json"),
    bpe_merges_path=os.path.join("gpt2_model", "vocab.bpe")
)

# %%
integers = tokenizer_gpt2.encode(text)

print(integers)
# Out:
# [15496, 11, 995, 13, 1148, 428, 438, 257, 1332, 30]

# %% [markdown]
# <br>
# &nbsp;
#
# ## 5. A quick performance benchmark

# %%
with open("../01_main-chapter-code/the-verdict.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

# %% [markdown]
# &nbsp;
# ### 5.1 Original OpenAI GPT-2 tokenizer

# %%
# %timeit orig_tokenizer.encode(raw_text)
# Out:
# 24.4 ms ± 2.11 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# &nbsp;
# ### 5.2 Tiktoken OpenAI GPT-2 tokenizer

# %%
# %timeit tik_tokenizer.encode(raw_text)
# Out:
# 7.55 ms ± 2.15 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# &nbsp;
# ### 5.3 Hugging Face OpenAI GPT-2 tokenizer

# %%
# %timeit hf_tokenizer(raw_text)["input_ids"]
# Out:
# [transformers] Token indices sequence length is longer than the specified maximum sequence length for this model (5145 > 1024). Running this sequence through the model will result in indexing errors
# 25.5 ms ± 2.29 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit hf_tokenizer(raw_text, max_length=5145, truncation=True)["input_ids"]
# Out:
# 14.7 ms ± 3.03 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit hf_tokenizer_fast(raw_text)["input_ids"]
# Out:
# [transformers] Token indices sequence length is longer than the specified maximum sequence length for this model (5145 > 1024). Running this sequence through the model will result in indexing errors
# 15.9 ms ± 2.88 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit hf_tokenizer_fast(raw_text, max_length=5145, truncation=True)["input_ids"]
# Out:
# 16 ms ± 3.03 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# &nbsp;
# ### 5.4 My own GPT-2 tokenizer (for educational purposes)

# %%
# %timeit tokenizer_gpt2.encode(raw_text)
# Out:
# 39.1 ms ± 889 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
